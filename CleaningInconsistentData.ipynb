# %%
import pandas as pd
import numpy as np

# %%
in_frame=pd.read_csv("inconsistent.tsv",sep='\t')

# %%
in_frame
# Out:
#          titleId  ordering                                              title  \
# 0      tt0112705         7                            Une étrange association
# 1      tt0112705         8                           Oudot yhteistyökumppanit
# 2      tt0112706         1                                      Come the Dawn
# 3      tt0112707         1                    A Comedy Salute to Andy Kaufman
# 4      tt0112708         1                                   Jóleső kábultság
# 5      tt0112708         2                                   Comfortably Numb
# 6      tt0112708         3                                   Comfortably Numb
# 7      tt0112709         1                     The Computer Wore Tennis Shoes
# 8      tt0112709         2                              O Computador de Tênis
# 9      tt0112709         3                              Le cerveau artificiel
# 10     tt0112709         4                             Komputer teniszcipőben
# ...

# %%
in_frame[['region','language','types','attributes']]=in_frame[['region','language','types','attributes']].replace('\\N',np.nan)

# %%
in_frame['isOriginalTitle']=in_frame['isOriginalTitle'].replace(np.nan,0)

# %%
in_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32869 entries, 0 to 32868
# Data columns (total 8 columns):
# titleId            32869 non-null object
# ordering           32869 non-null int64
# title              32869 non-null object
# region             32869 non-null object
# language           32869 non-null object
# types              32869 non-null object
# attributes         32869 non-null object
# isOriginalTitle    32869 non-null object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ MB

# %%
in_frame['isOriginalTitle']=in_frame['isOriginalTitle'].astype(bool)

# %%
in_frame
# Out:
#          titleId  ordering                                              title  \
# 0      tt0112705         7                            Une étrange association
# 1      tt0112705         8                           Oudot yhteistyökumppanit
# 2      tt0112706         1                                      Come the Dawn
# 3      tt0112707         1                    A Comedy Salute to Andy Kaufman
# 4      tt0112708         1                                   Jóleső kábultság
# 5      tt0112708         2                                   Comfortably Numb
# 6      tt0112708         3                                   Comfortably Numb
# 7      tt0112709         1                     The Computer Wore Tennis Shoes
# 8      tt0112709         2                              O Computador de Tênis
# 9      tt0112709         3                              Le cerveau artificiel
# 10     tt0112709         4                             Komputer teniszcipőben
# ...

# %%
in_frame.isnull().sum()
# Out:
# titleId            0
# ordering           0
# title              0
# region             0
# language           0
# types              0
# attributes         0
# isOriginalTitle    0
# dtype: int64

# %%
in_frame.to_csv('Desktop/corrected.csv',index=False)
