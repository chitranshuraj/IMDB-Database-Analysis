# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("title.akas.tsv",sep='\t')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#            titleId  ordering  \
# 0        tt0000001         1
# 1        tt0000001         2
# 2        tt0000001         3
# 3        tt0000001         4
# 4        tt0000001         5
# 5        tt0000002         1
# 6        tt0000002         2
# 7        tt0000002         3
# 8        tt0000002         4
# 9        tt0000002         5
# 10       tt0000002         6
# 11       tt0000003         1
# 12       tt0000003         2
# 13       tt0000003         3
# 14       tt0000003         4
# 15       tt0000003         5
# 16       tt0000003         6
# 17       tt0000004         1
# 18       tt0000004         2
# 19       tt0000004         3
# 20       tt0000004         4
# 21       tt0000004         5
# 22       tt0000004         6
# 23       tt0000005         1
# 24       tt0000005         2
# 25       tt0000005         3
# 26       tt0000005         4
# 27       tt0000005         5
# 28       tt0000005         6
# 29       tt0000005         7
# ...            ...       ...
# ...

# %%
df['titleId'].nunique()
# Out:
# 2073682

# %%
df2=pd.read_csv('title.basics.tsv',sep='\t')

# %%
df2[['startYear','endYear']]=df2[['startYear','endYear']].replace('\\N',np.nan)

# %%
df2[['startYear','endYear']]=df2[['startYear','endYear']].replace(np.nan,0)

# %%
df2
# Out:
#             tconst  titleType                                   primaryTitle  \
# 0        tt0000001      short                                     Carmencita
# 1        tt0000002      short                         Le clown et ses chiens
# 2        tt0000003      short                                 Pauvre Pierrot
# 3        tt0000004      short                                    Un bon bock
# 4        tt0000005      short                               Blacksmith Scene
# 5        tt0000006      short                              Chinese Opium Den
# 6        tt0000007      short    Corbett and Courtney Before the Kinetograph
# 7        tt0000008      short         Edison Kinetoscopic Record of a Sneeze
# 8        tt0000009      movie                                     Miss Jerry
# 9        tt0000010      short                            Exiting the Factory
# 10       tt0000011      short                        Akrobatisches Potpourri
# ...

# %%
df2['startYear']=df2['startYear'].astype(int)

# %%
df2['endYear']=df2['endYear'].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5797087 entries, 0 to 5797086
# Data columns (total 9 columns):
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           int64
# startYear         int32
# endYear           int32
# runtimeMinutes    object
# genres            object
# dtypes: int32(2), int64(1), object(6)
# memory usage: 353.8+ MB

# %%
df2['isAdult']=df2['isAdult'].astype(bool)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5797087 entries, 0 to 5797086
# Data columns (total 9 columns):
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           bool
# startYear         int32
# endYear           int32
# runtimeMinutes    object
# genres            object
# dtypes: bool(1), int32(2), object(6)
# memory usage: 315.1+ MB

# %%
df2[['runtimeMinutes']]=df2[['runtimeMinutes']].replace(0,25)

# %%
df2[['runtimeMinutes']]=df2[['runtimeMinutes']].replace('\\N',0)

# %%
df2[['runtimeMinutes']]=df2[['runtimeMinutes']].replace('Reality-TV',25)

# %%
df2[['runtimeMinutes']]=df2[['runtimeMinutes']].replace('Animation,Family',30)

# %%
df2[['runtimeMinutes']]=df2[['runtimeMinutes']].replace('Animation,Comedy,Drama',30)

# %%
df2['runtimeMinutes']=df2['runtimeMinutes'].astype(int)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5797087 entries, 0 to 5797086
# Data columns (total 9 columns):
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           bool
# startYear         int32
# endYear           int32
# runtimeMinutes    int32
# genres            object
# dtypes: bool(1), int32(3), object(5)
# memory usage: 293.0+ MB

# %%
df2
# Out:
#             tconst  titleType                                   primaryTitle  \
# 0        tt0000001      short                                     Carmencita
# 1        tt0000002      short                         Le clown et ses chiens
# 2        tt0000003      short                                 Pauvre Pierrot
# 3        tt0000004      short                                    Un bon bock
# 4        tt0000005      short                               Blacksmith Scene
# 5        tt0000006      short                              Chinese Opium Den
# 6        tt0000007      short    Corbett and Courtney Before the Kinetograph
# 7        tt0000008      short         Edison Kinetoscopic Record of a Sneeze
# 8        tt0000009      movie                                     Miss Jerry
# 9        tt0000010      short                            Exiting the Factory
# 10       tt0000011      short                        Akrobatisches Potpourri
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5797087 entries, 0 to 5797086
# Data columns (total 9 columns):
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           bool
# startYear         int32
# endYear           int32
# runtimeMinutes    int32
# genres            object
# dtypes: bool(1), int32(3), object(5)
# memory usage: 293.0+ MB

# %%
mask=df2['startYear']>1990

# %%
df3=df2[mask]

# %%
mask2=df3['startYear']<2005

# %%
newdf=df3[mask2]

# %%
len(newdf)
# Out:
# 981481

# %%
newdf['titleType'].unique()
# Out:
# array(['movie', 'short', 'video', 'tvEpisode', 'tvSeries', 'tvMovie',
#        'tvMiniSeries', 'tvShort', 'tvSpecial', 'videoGame'], dtype=object)

# %%
newdf.reset_index()
# Out:
#           index     tconst     titleType  \
# 0         15495  tt0015724         movie
# 1         34821  tt0035423         movie
# 2         40155  tt0040844         short
# 3         65137  tt0066435         video
# 4         71826  tt0073303         video
# 5         71997  tt0073481     tvEpisode
# 6         75840  tt0077432         movie
# 7         76406  tt0078006         short
# 8         78542  tt0080217      tvSeries
# 9         79320  tt0081008         movie
# 10        79453  tt0081145         movie
# 11        82237  tt0084015         movie
# 12        82268  tt0084046         short
# 13        82756  tt0084551         movie
# 14        83062  tt0084870         movie
# 15        85259  tt0087126         movie
# 16        85436  tt0087305      tvSeries
# 17        86375  tt0088267         movie
# 18        86570  tt0088472      tvSeries
# 19        86571  tt0088473      tvSeries
# 20        87133  tt0089043         movie
# 21        87619  tt0089544       tvMovie
# ...

# %%
newdf.reset_index(inplace=True)

# %%
newdf
# Out:
#           index     tconst     titleType  \
# 0         15495  tt0015724         movie
# 1         34821  tt0035423         movie
# 2         40155  tt0040844         short
# 3         65137  tt0066435         video
# 4         71826  tt0073303         video
# 5         71997  tt0073481     tvEpisode
# 6         75840  tt0077432         movie
# 7         76406  tt0078006         short
# 8         78542  tt0080217      tvSeries
# 9         79320  tt0081008         movie
# 10        79453  tt0081145         movie
# 11        82237  tt0084015         movie
# 12        82268  tt0084046         short
# 13        82756  tt0084551         movie
# 14        83062  tt0084870         movie
# 15        85259  tt0087126         movie
# 16        85436  tt0087305      tvSeries
# 17        86375  tt0088267         movie
# 18        86570  tt0088472      tvSeries
# 19        86571  tt0088473      tvSeries
# 20        87133  tt0089043         movie
# 21        87619  tt0089544       tvMovie
# ...

# %%
newdf.drop(labels="index",axis=1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
newdf
# Out:
#            tconst     titleType  \
# 0       tt0015724         movie
# 1       tt0035423         movie
# 2       tt0040844         short
# 3       tt0066435         video
# 4       tt0073303         video
# 5       tt0073481     tvEpisode
# 6       tt0077432         movie
# 7       tt0078006         short
# 8       tt0080217      tvSeries
# 9       tt0081008         movie
# 10      tt0081145         movie
# 11      tt0084015         movie
# 12      tt0084046         short
# 13      tt0084551         movie
# 14      tt0084870         movie
# 15      tt0087126         movie
# 16      tt0087305      tvSeries
# 17      tt0088267         movie
# 18      tt0088472      tvSeries
# 19      tt0088473      tvSeries
# 20      tt0089043         movie
# 21      tt0089544       tvMovie
# 22      tt0089749  tvMiniSeries
# 23      tt0090144         short
# 24      tt0090780     tvEpisode
# 25      tt0092024         movie
# 26      tt0092443      tvSeries
# 27      tt0092507         movie
# ...

# %%
newdf.set_index(['tconst'])
# Out:
#               titleType                                       primaryTitle  \
# tconst
# tt0015724         movie                                      Dama de noche
# tt0035423         movie                                     Kate & Leopold
# tt0040844         short                               Crossroads of Laredo
# tt0066435         video                 Take It Out in Trade: The Outtakes
# tt0073303         video                                Live at the Rainbow
# tt0073481     tvEpisode                                          Old Times
# tt0077432         movie                                  Dip huet kei bing
# tt0078006         short                              Norman and the Killer
# tt0080217      tvSeries                      Hana no mahoutsukai Mary Bell
# tt0081008         movie                                   Kommen und gehen
# tt0081145         movie                                     Me and the Kid
# ...

# %%
array1 = newdf['tconst'].values

# %%
tconst_list=array1.tolist()

# %%
tconst_list
# Out:
# ['tt0015724',
#  'tt0035423',
#  'tt0040844',
#  'tt0066435',
#  'tt0073303',
#  'tt0073481',
#  'tt0077432',
#  'tt0078006',
#  'tt0080217',
#  'tt0081008',
#  'tt0081145',
#  'tt0084015',
#  'tt0084046',
#  'tt0084551',
#  'tt0084870',
#  'tt0087126',
#  'tt0087305',
#  'tt0088267',
#  'tt0088472',
#  'tt0088473',
#  'tt0089043',
#  'tt0089544',
#  'tt0089749',
#  'tt0090144',
#  'tt0090780',
#  'tt0092024',
#  'tt0092443',
#  'tt0092507',
#  'tt0092592',
#  'tt0093061',
#  'tt0093309',
#  'tt0094045',
#  'tt0094547',
#  'tt0094609',
#  'tt0094688',
#  'tt0094808',
#  'tt0094830',
#  'tt0094841',
#  'tt0094900',
#  'tt0094926',
#  'tt0094943',
#  'tt0095083',
#  'tt0095111',
#  'tt0095138',
#  'tt0095229',
#  'tt0095335',
#  'tt0095394',
#  'tt0095401',
#  'tt0095450',
#  'tt0095469',
#  'tt0095571',
#  'tt0095661',
#  'tt0095761',
#  'tt0095831',
#  'tt0095941',
#  'tt0096038',
#  'tt0096056',
#  'tt0096090',
#  'tt0096154',
#  'tt0096222',
#  'tt0096346',
#  'tt0096361',
# ...

# %%
tconst_df=pd.DataFrame(tconst_list,columns=["tconst"])

# %%
tconst_df.to_csv('Desktop/tconst_list_1990-2005.csv',index=False)

# %%
newdf[['genres']]=newdf[['genres']].replace('abstract','Abstract')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
newdf
# Out:
#            tconst     titleType  \
# 0       tt0015724         movie
# 1       tt0035423         movie
# 2       tt0040844         short
# 3       tt0066435         video
# 4       tt0073303         video
# 5       tt0073481     tvEpisode
# 6       tt0077432         movie
# 7       tt0078006         short
# 8       tt0080217      tvSeries
# 9       tt0081008         movie
# 10      tt0081145         movie
# 11      tt0084015         movie
# 12      tt0084046         short
# 13      tt0084551         movie
# 14      tt0084870         movie
# 15      tt0087126         movie
# 16      tt0087305      tvSeries
# 17      tt0088267         movie
# 18      tt0088472      tvSeries
# 19      tt0088473      tvSeries
# 20      tt0089043         movie
# 21      tt0089544       tvMovie
# 22      tt0089749  tvMiniSeries
# 23      tt0090144         short
# 24      tt0090780     tvEpisode
# 25      tt0092024         movie
# 26      tt0092443      tvSeries
# 27      tt0092507         movie
# ...

# %%
newdf.to_csv('Desktop/Title_Information_1990-2005.csv',index=False)

# %%
df
# Out:
#            titleId  ordering  \
# 0        tt0000001         1
# 1        tt0000001         2
# 2        tt0000001         3
# 3        tt0000001         4
# 4        tt0000001         5
# 5        tt0000002         1
# 6        tt0000002         2
# 7        tt0000002         3
# 8        tt0000002         4
# 9        tt0000002         5
# 10       tt0000002         6
# 11       tt0000003         1
# 12       tt0000003         2
# 13       tt0000003         3
# 14       tt0000003         4
# 15       tt0000003         5
# 16       tt0000003         6
# 17       tt0000004         1
# 18       tt0000004         2
# 19       tt0000004         3
# 20       tt0000004         4
# 21       tt0000004         5
# 22       tt0000004         6
# 23       tt0000005         1
# 24       tt0000005         2
# 25       tt0000005         3
# 26       tt0000005         4
# 27       tt0000005         5
# 28       tt0000005         6
# 29       tt0000005         7
# ...            ...       ...
# ...

# %%
dataframe=df.loc[df['titleId'].isin(tconst_list)]

# %%
len(dataframe)
# Out:
# 651780

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 651780 entries, 41154 to 3653794
# Data columns (total 8 columns):
# titleId            651780 non-null object
# ordering           651780 non-null int64
# title              651780 non-null object
# region             651776 non-null object
# language           651780 non-null object
# types              651780 non-null object
# attributes         651780 non-null object
# isOriginalTitle    651780 non-null object
# dtypes: int64(1), object(7)
# memory usage: 44.8+ MB

# %%
dataframe.reset_index(inplace=True)

# %%
dataframe.
# Out:
#           index    titleId  ordering  \
# 0         41154  tt0015724         1
# 1         41155  tt0015724         2
# 2         41156  tt0015724         3
# 3         41157  tt0015724         4
# 4        149935  tt0035423        10
# 5        149936  tt0035423        11
# 6        149937  tt0035423        12
# 7        149938  tt0035423        13
# 8        149939  tt0035423        14
# 9        149940  tt0035423        15
# 10       149941  tt0035423        16
# 11       149942  tt0035423        17
# 12       149943  tt0035423        18
# 13       149944  tt0035423        19
# 14       149945  tt0035423         1
# 15       149946  tt0035423        20
# 16       149947  tt0035423        21
# 17       149948  tt0035423        22
# 18       149949  tt0035423        23
# 19       149950  tt0035423        24
# 20       149951  tt0035423        25
# 21       149952  tt0035423        26
# 22       149953  tt0035423        27
# 23       149954  tt0035423        28
# ...

# %%
dataframe.drop(labels="index",axis=1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
dataframe.set_index(['titleId'])
# Out:
#            ordering                                              title region  \
# titleId
# tt0015724         1                                      Dama de noche     MX
# tt0015724         2                                      Dama de noche     \N
# tt0015724         3                                Éjszakai gyilkosság     HU
# tt0015724         4                                  Lady of the Night     \N
# tt0035423        10                                   Kate und Leopold     DE
# tt0035423        11                                    Kate ja Leopold     EE
# tt0035423        12                                    Kate & Leopoldo     CO
# tt0035423        13                                 Keite ir Leopoldas     LT
# tt0035423        14                                    Kate et Léopold     CA
# tt0035423        15                                     Kaća i Leopold     RS
# tt0035423        16                                    Kate & Leopoldo     PE
# ...

# %%
dataframe[['attributes']]=dataframe[['attributes']].replace('\\N','title')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
dataframe[['types']]=dataframe[['types']].replace('No Info','no info')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
dataframe[['language']]=dataframe[['language']].replace('NA','n/a')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
dataframe.isnull().sum()
# Out:
# titleId            0
# ordering           0
# title              0
# region             0
# language           0
# types              0
# attributes         0
# isOriginalTitle    0
# dtype: int64

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651780 entries, 0 to 651779
# Data columns (total 8 columns):
# titleId            651780 non-null object
# ordering           651780 non-null int64
# title              651780 non-null object
# region             651780 non-null object
# language           651780 non-null object
# types              651780 non-null object
# attributes         651780 non-null object
# isOriginalTitle    651780 non-null object
# dtypes: int64(1), object(7)
# memory usage: 39.8+ MB

# %%
dataframe['isOriginalTitle']=dataframe['isOriginalTitle'].astype(bool)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dataframe['ordering']=dataframe['ordering'].astype(int)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651780 entries, 0 to 651779
# Data columns (total 8 columns):
# titleId            651780 non-null object
# ordering           651780 non-null int32
# title              651780 non-null object
# region             651780 non-null object
# language           651780 non-null object
# types              651780 non-null object
# attributes         651780 non-null object
# isOriginalTitle    651780 non-null bool
# dtypes: bool(1), int32(1), object(6)
# memory usage: 32.9+ MB

# %%
dataframe.to_csv('Desktop/Title_1990-2005.csv',index=False)

# %%
newdf.isnull().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %%
edf=pd.read_csv('Desktop/principals_crewinfo.csv')

# %%
edf
# Out:
#              tconst  ordering     nconst         category  \
# 0         tt0000001         1  nm1588970             self
# 1         tt0000001         2  nm0005690         director
# 2         tt0000001         3  nm0374658  cinematographer
# 3         tt0000002         1  nm0721526         director
# 4         tt0000002         2  nm1335271         composer
# 5         tt0000003         1  nm0721526         director
# 6         tt0000003         2  nm5442194         producer
# 7         tt0000003         3  nm1335271         composer
# 8         tt0000003         4  nm5442200           editor
# 9         tt0000004         1  nm0721526         director
# 10        tt0000004         2  nm1335271         composer
# 11        tt0000005         1  nm0443482            actor
# 12        tt0000005         2  nm0653042            actor
# 13        tt0000005         3  nm0005690         director
# 14        tt0000005         4  nm0249379         producer
# ...

# %%
imp_df=edf.loc[edf['tconst'].isin(tconst_list)]

# %%
len(imp_df)
# Out:
# 6177618

# %%
imp_df.reset_index()
# Out:
#             index     tconst  ordering     nconst             category  \
# 0          112468  tt0015724        10  nm1457911               editor
# 1          112469  tt0015724         1  nm0844752                actor
# 2          112470  tt0015724         2  nm0869732              actress
# 3          112471  tt0015724         3  nm0194720                actor
# 4          112472  tt0015724         4  nm0650495              actress
# 5          112473  tt0015724         5  nm0529960             director
# 6          112474  tt0015724         6  nm1597742               writer
# 7          112475  tt0015724         7  nm0600039             producer
# 8          112476  tt0015724         8  nm0255550             composer
# 9          112477  tt0015724         9  nm0006509      cinematographer
# 10         280730  tt0035423        10  nm0107463               editor
# 11         280731  tt0035423         1  nm0000212              actress
# ...

# %%
imp_df.set_index(['tconst'])
# Out:
#            ordering     nconst             category                characters
# tconst
# tt0015724        10  nm1457911               editor                       NaN
# tt0015724         1  nm0844752                actor                 ["Bruno"]
# tt0015724         2  nm0869732              actress                 ["Sofía"]
# tt0015724         3  nm0194720                actor        ["Rolando Matute"]
# tt0015724         4  nm0650495              actress                ["Salomé"]
# tt0015724         5  nm0529960             director                       NaN
# tt0015724         6  nm1597742               writer                       NaN
# tt0015724         7  nm0600039             producer                       NaN
# tt0015724         8  nm0255550             composer                       NaN
# tt0015724         9  nm0006509      cinematographer                       NaN
# tt0035423        10  nm0107463               editor                       NaN
# ...

# %%
imp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6177618 entries, 112468 to 33268989
# Data columns (total 5 columns):
# tconst        object
# ordering      int64
# nconst        object
# category      object
# characters    object
# dtypes: int64(1), object(4)
# memory usage: 442.8+ MB

# %%
imp_df['ordering']=imp_df['ordering'].astype(int)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
imp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6177618 entries, 112468 to 33268989
# Data columns (total 5 columns):
# tconst        object
# ordering      int32
# nconst        object
# category      object
# characters    object
# dtypes: int32(1), object(4)
# memory usage: 419.2+ MB

# %%
imp_df.isnull().sum()
# Out:
# tconst              0
# ordering            0
# nconst              0
# category            0
# characters    2994508
# dtype: int64

# %%
imp_df[['characters']]=imp_df[['characters']].replace(np.nan,'no info')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
imp_df.isnull().sum()
# Out:
# tconst        0
# ordering      0
# nconst        0
# category      0
# characters    0
# dtype: int64

# %%
imp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6177618 entries, 112468 to 33268989
# Data columns (total 5 columns):
# tconst        object
# ordering      int32
# nconst        object
# category      object
# characters    object
# dtypes: int32(1), object(4)
# memory usage: 419.2+ MB

# %%
imp_df.to_csv('Desktop/Principal_CrewInfo_1990-2005.csv',index=False)

# %%
array2 = imp_df['nconst'].values

# %%
array2
# Out:
# array(['nm1457911', 'nm0844752', 'nm0869732', ..., 'nm0407831',
#        'nm0407831', 'nm0407831'], dtype=object)

# %%
nconst_list=array2.tolist()

# %%
ndf=pd.DataFrame(nconst_list,columns=["nconst"])

# %%
ndf.to_csv('Desktop/nconst_list_1990-2005.csv',index=False)

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6177618 entries, 0 to 6177617
# Data columns (total 1 columns):
# nconst    object
# dtypes: object(1)
# memory usage: 47.1+ MB

# %%
adf=pd.read_csv('Desktop/person_information_2.csv')

# %%
adf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7141626 entries, 0 to 7141625
# Data columns (total 6 columns):
# nconst               object
# primaryName          object
# birthYear            int64
# deathYear            int64
# primaryProfession    object
# knownForTitles       object
# dtypes: int64(2), object(4)
# memory usage: 326.9+ MB

# %%
new_adf=adf.loc[adf['nconst'].isin(nconst_list)]

# %%
new_adf.reset_index(inplace=True)

# %%
new_adf['deathYear']=new_adf['deathYear'].replace(0,2020)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
mask4=new_adf['deathYear']>1990

# %%
nn_adf=new_adf[mask4]

# %%
nn_adf.drop(labels="index",axis=1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
nn_adf.reset_index(inplace=True)

# %%
nn_adf
# Out:
#            nconst           primaryName  birthYear  deathYear  \
# 0       nm0000002         Lauren Bacall       1924       2014
# 1       nm0000003       Brigitte Bardot       1934       2020
# 2       nm0000005        Ingmar Bergman       1918       2007
# 3       nm0000008         Marlon Brando       1924       2004
# 4       nm0000013             Doris Day       1922       2020
# 5       nm0000014   Olivia de Havilland       1916       2020
# 6       nm0000016       Georges Delerue       1925       1992
# 7       nm0000017      Marlene Dietrich       1901       1992
# 8       nm0000018          Kirk Douglas       1916       2020
# 9       nm0000019      Federico Fellini       1920       1993
# 10      nm0000024          John Gielgud       1904       2000
# 11      nm0000025       Jerry Goldsmith       1929       2004
# 12      nm0000027         Alec Guinness       1914       2000
# 13      nm0000029     Margaux Hemingway       1954       1996
# ...

# %%
new_adf
# Out:
#           index     nconst          primaryName  birthYear  deathYear  \
# 0             0  nm0000001         Fred Astaire       1899       1987
# 1             1  nm0000002        Lauren Bacall       1924       2014
# 2             2  nm0000003      Brigitte Bardot       1934       2020
# 3             3  nm0000004         John Belushi       1949       1982
# 4             4  nm0000005       Ingmar Bergman       1918       2007
# 5             5  nm0000006       Ingrid Bergman       1915       1982
# 6             6  nm0000007      Humphrey Bogart       1899       1957
# 7             7  nm0000008        Marlon Brando       1924       2004
# 8             8  nm0000009       Richard Burton       1925       1984
# 9             9  nm0000010         James Cagney       1899       1986
# 10           10  nm0000011          Gary Cooper       1901       1961
# 11           11  nm0000012          Bette Davis       1908       1989
# ...

# %%
new_adf.drop(labels="index",axis=1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
new_adf['deathYear']=new_adf['deathYear'].replace(2020,0)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_adf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661161 entries, 0 to 661160
# Data columns (total 6 columns):
# nconst               661161 non-null object
# primaryName          661161 non-null object
# birthYear            661161 non-null int64
# deathYear            661161 non-null int64
# primaryProfession    661161 non-null object
# knownForTitles       661161 non-null object
# dtypes: int64(2), object(4)
# memory usage: 30.3+ MB

# %%
new_adf['deathYear']=new_adf['deathYear'].astype(int)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_adf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661161 entries, 0 to 661160
# Data columns (total 6 columns):
# nconst               661161 non-null object
# primaryName          661161 non-null object
# birthYear            661161 non-null int32
# deathYear            661161 non-null int32
# primaryProfession    661161 non-null object
# knownForTitles       661161 non-null object
# dtypes: int32(2), object(4)
# memory usage: 25.2+ MB

# %%
new_adf.to_csv('Desktop/Personal_Information_1990-2005.csv',index=False)

# %%
len(new_adf)
# Out:
# 661161

# %%
ratdf=pd.read_csv('title.ratings.tsv',sep='\t')

# %%
ratdf
# Out:
#            tconst  averageRating  numVotes
# 0       tt0000001            5.8      1488
# 1       tt0000002            6.3       180
# 2       tt0000003            6.6      1120
# 3       tt0000004            6.4       110
# 4       tt0000005            6.2      1821
# 5       tt0000006            5.5        96
# 6       tt0000007            5.5       597
# 7       tt0000008            5.6      1589
# 8       tt0000009            5.5        78
# 9       tt0000010            6.9      5296
# 10      tt0000011            5.4       219
# 11      tt0000012            7.4      8977
# 12      tt0000013            5.8      1375
# 13      tt0000014            7.2      3911
# 14      tt0000015            6.2       695
# 15      tt0000016            5.9      1019
# 16      tt0000017            4.8       202
# 17      tt0000018            5.5       425
# 18      tt0000019            6.6        13
# 19      tt0000020            5.1       233
# 20      tt0000022            5.2       765
# ...

# %%
ratingframe=ratdf.loc[ratdf['tconst'].isin(tconst_list)]

# %%
ratingframe
# Out:
#            tconst  averageRating  numVotes
# 3810    tt0015724            6.2        20
# 16754   tt0035423            6.4     73766
# 21047   tt0040844            3.8       161
# 42353   tt0066435            5.6        47
# 48255   tt0073303            8.4       143
# 48387   tt0073481            7.9        38
# 51716   tt0077432            6.7         6
# 52207   tt0078006            7.3        24
# 54082   tt0080217            7.1        15
# 54884   tt0081145            5.3       207
# 57317   tt0084015            7.3        39
# 57343   tt0084046            7.3       380
# 57757   tt0084551            5.8        10
# 58018   tt0084870            7.4       186
# 59916   tt0087126            5.8        69
# 60061   tt0087305            7.3       112
# 60859   tt0088267            5.6        70
# 61024   tt0088472            7.8        21
# 61025   tt0088473            8.2       485
# 61949   tt0089544            5.4        26
# 62123   tt0089749            7.4       450
# ...

# %%
ratingframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193365 entries, 3810 to 924945
# Data columns (total 3 columns):
# tconst           193365 non-null object
# averageRating    193365 non-null float64
# numVotes         193365 non-null int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 5.9+ MB

# %%
ratingframe['numVotes']=ratingframe['numVotes'].astype(int)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ratingframe['averageRating']=ratingframe['averageRating'].astype(float)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ratingframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193365 entries, 3810 to 924945
# Data columns (total 3 columns):
# tconst           193365 non-null object
# averageRating    193365 non-null float64
# numVotes         193365 non-null int32
# dtypes: float64(1), int32(1), object(1)
# memory usage: 5.2+ MB

# %%
ratingframe.reset_index(inplace=True)

# %%
ratingframe.drop(labels="index",axis=1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
ratingframe
# Out:
#            tconst  averageRating  numVotes
# 0       tt0015724            6.2        20
# 1       tt0035423            6.4     73766
# 2       tt0040844            3.8       161
# 3       tt0066435            5.6        47
# 4       tt0073303            8.4       143
# 5       tt0073481            7.9        38
# 6       tt0077432            6.7         6
# 7       tt0078006            7.3        24
# 8       tt0080217            7.1        15
# 9       tt0081145            5.3       207
# 10      tt0084015            7.3        39
# 11      tt0084046            7.3       380
# 12      tt0084551            5.8        10
# 13      tt0084870            7.4       186
# 14      tt0087126            5.8        69
# 15      tt0087305            7.3       112
# 16      tt0088267            5.6        70
# 17      tt0088472            7.8        21
# 18      tt0088473            8.2       485
# 19      tt0089544            5.4        26
# 20      tt0089749            7.4       450
# ...

# %%
ratingframe.to_csv('Desktop/Ratings_1990-2005.csv',index=False)

# %%
cr_df=pd.read_csv('title.crew.tsv',sep='\t')

# %%
cr_df
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# 5        tt0000006            nm0005690                             \N
# 6        tt0000007  nm0005690,nm0374658                             \N
# 7        tt0000008            nm0005690                             \N
# 8        tt0000009            nm0085156                      nm0085156
# 9        tt0000010            nm0525910                             \N
# 10       tt0000011            nm0804434                             \N
# 11       tt0000012  nm0525908,nm0525910                             \N
# ...

# %%
crewframe=cr_df.loc[cr_df['tconst'].isin(tconst_list)]

# %%
crewframe.reset_index(inplace=True)

# %%
crewframe.drop(labels="index",axis=1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
crewframe
# Out:
#            tconst                                          directors  \
# 0       tt0015724                                          nm0529960
# 1       tt0035423                                          nm0003506
# 2       tt0040844                                          nm0000248
# 3       tt0066435                                          nm0000248
# 4       tt0073303                                                 \N
# 5       tt0073481                                          nm0193508
# 6       tt0077432                                          nm0839288
# 7       tt0078006                                          nm0333937
# 8       tt0080217  nm0652951,nm1628149,nm2569616,nm1572430,nm4059...
# 9       tt0081008                                          nm0389846
# 10      tt0081145                                          nm0193303
# 11      tt0084015                                nm0160246,nm0767391
# 12      tt0084046                                          nm0452102
# ...

# %%
crewframe2['directors']=crewframe2['directors'].replace(np.nan,'N\A')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
crewframe
# Out:
#            tconst                                          directors  \
# 0       tt0015724                                          nm0529960
# 1       tt0035423                                          nm0003506
# 2       tt0040844                                          nm0000248
# 3       tt0066435                                          nm0000248
# 4       tt0073303                                                NaN
# 5       tt0073481                                          nm0193508
# 6       tt0077432                                          nm0839288
# 7       tt0078006                                          nm0333937
# 8       tt0080217  nm0652951,nm1628149,nm2569616,nm1572430,nm4059...
# 9       tt0081008                                          nm0389846
# 10      tt0081145                                          nm0193303
# 11      tt0084015                                nm0160246,nm0767391
# 12      tt0084046                                          nm0452102
# ...

# %%
crewframe2=crewframe.dropna(subset=['directors', 'writers'], how='all')

# %%
crewframe2
# Out:
#            tconst                                          directors  \
# 0       tt0015724                                          nm0529960
# 1       tt0035423                                          nm0003506
# 2       tt0040844                                          nm0000248
# 3       tt0066435                                          nm0000248
# 5       tt0073481                                          nm0193508
# 6       tt0077432                                          nm0839288
# 7       tt0078006                                          nm0333937
# 8       tt0080217  nm0652951,nm1628149,nm2569616,nm1572430,nm4059...
# 9       tt0081008                                          nm0389846
# 10      tt0081145                                          nm0193303
# 11      tt0084015                                nm0160246,nm0767391
# 12      tt0084046                                          nm0452102
# 13      tt0084551                                          nm0152049
# ...

# %%
crewframe2.reset_index(inplace=True)

# %%
crewframe2.drop(labels='index',axis=1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
crewframe2
# Out:
#            tconst                                          directors  \
# 0       tt0015724                                          nm0529960
# 1       tt0035423                                          nm0003506
# 2       tt0040844                                          nm0000248
# 3       tt0066435                                          nm0000248
# 4       tt0073481                                          nm0193508
# 5       tt0077432                                          nm0839288
# 6       tt0078006                                          nm0333937
# 7       tt0080217  nm0652951,nm1628149,nm2569616,nm1572430,nm4059...
# 8       tt0081008                                          nm0389846
# 9       tt0081145                                          nm0193303
# 10      tt0084015                                nm0160246,nm0767391
# 11      tt0084046                                          nm0452102
# 12      tt0084551                                          nm0152049
# ...

# %%
crewframe2.to_csv('Desktop/Titles_Crew_1990-2005.csv',index=False)

# %%
ep_df=pd.read_csv('title.episode.tsv',sep='\t')

# %%
ep_df
# Out:
#             tconst parentTconst seasonNumber episodeNumber
# 0        tt0041951    tt0041038            1             9
# 1        tt0042816    tt0989125            1            17
# 2        tt0042889    tt0989125           \N            \N
# 3        tt0043426    tt0040051            3            42
# 4        tt0043631    tt0989125            2            16
# 5        tt0043693    tt0989125            2             8
# 6        tt0043710    tt0989125            3             3
# 7        tt0044093    tt0959862            1             6
# 8        tt0044901    tt0989125            3            46
# 9        tt0045519    tt0989125            4            11
# 10       tt0045960    tt0044284            2             3
# 11       tt0046135    tt0989125            4             5
# 12       tt0046150    tt0341798           \N            \N
# 13       tt0046855    tt0046643            1             4
# 14       tt0046864    tt0989125            5            20
# ...

# %%
new_ep=ep_df.loc[ep_df['parentTconst'].isin(tconst_list)]

# %%
new_ep
# Out:
#             tconst parentTconst seasonNumber episodeNumber
# 799      tt0073481    tt0298685            1             3
# 1264     tt0090780    tt0190210            1             3
# 1410     tt0094808    tt0882736            1             1
# 1450     tt0095518    tt0159156           \N            \N
# 1486     tt0096361    tt0158415            1             4
# 1487     tt0096362    tt0158415            1             1
# 1488     tt0096363    tt0158415            1             2
# 1562     tt0098576    tt0158415            1             3
# 1629     tt0101274    tt0346328            1             1
# 1633     tt0101480    tt0139780            1             5
# 1639     tt0101750    tt0298685            2             2
# 1646     tt0102143    tt2138025           \N            \N
# 1647     tt0102144    tt2138025           \N            \N
# 1648     tt0102145    tt2138025           \N            \N
# 1649     tt0102172    tt0102171            1             2
# ...

# %%
new_ep2=ep_df.loc[ep_df['tconst'].isin(tconst_list)]

# %%
new_ep2
# Out:
#             tconst parentTconst seasonNumber episodeNumber
# 799      tt0073481    tt0298685            1             3
# 1264     tt0090780    tt0190210            1             3
# 1410     tt0094808    tt0882736            1             1
# 1453     tt0095661    tt3782882           \N            \N
# 1486     tt0096361    tt0158415            1             4
# 1487     tt0096362    tt0158415            1             1
# 1488     tt0096363    tt0158415            1             2
# 1493     tt0096781    tt1615489            2             2
# 1561     tt0098553    tt1342141            1             3
# 1562     tt0098576    tt0158415            1             3
# 1568     tt0099003    tt0297626            7            12
# 1571     tt0099139    tt0313144           \N            \N
# 1578     tt0099427    tt1342141            1             2
# 1588     tt0099781    tt0176357           10             4
# 1591     tt0099851    tt0176357           10             1
# ...

# %%
new_ep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1032242 entries, 799 to 4010594
# Data columns (total 4 columns):
# tconst           1032242 non-null object
# parentTconst     1032242 non-null object
# seasonNumber     1032242 non-null object
# episodeNumber    1032242 non-null object
# dtypes: object(4)
# memory usage: 39.4+ MB

# %%
new_ep[['seasonNumber','episodeNumber']]=new_ep[['seasonNumber','episodeNumber']].replace(np.nan,0)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
new_ep['episodeNumber']=new_ep['episodeNumber'].astype(int)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_ep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1032242 entries, 799 to 4010594
# Data columns (total 4 columns):
# tconst           1032242 non-null object
# parentTconst     1032242 non-null object
# seasonNumber     1032242 non-null int32
# episodeNumber    1032242 non-null int32
# dtypes: int32(2), object(2)
# memory usage: 31.5+ MB

# %%
new_ep.reset_index(inplace=True)

# %%
new_ep.drop(labels="index",axis=1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
new_ep.to_csv('Desktop/Episode_Information_1990-2005.csv',index=False)
