# %%
import pandas as pd
import numpy as np

# %%
dframe=pd.read_csv("C:\Users\hp\Desktop\UFL STUDY\DBMS\Project\IMDB\name.basics.tsv",sep='\t')
# Out:
#   File "<ipython-input-3-7a37f1a56cfe>", line 1
#     dframe=pd.read_csv("C:\Users\hp\Desktop\UFL STUDY\DBMS\Project\IMDB\name.basics.tsv",sep='\t')
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
dframe=pd.read_csv("name.basics.tsv",sep='\t')

# %%
dframe.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                 primaryProfession                           knownForTitles
# 0  soundtrack,actor,miscellaneous  tt0043044,tt0050419,tt0053137,tt0072308
# 1              actress,soundtrack  tt0071877,tt0037382,tt0117057,tt0038355
# 2     actress,soundtrack,producer  tt0049189,tt0054452,tt0059956,tt0057345
# 3         actor,writer,soundtrack  tt0080455,tt0072562,tt0077975,tt0078723
# 4           writer,director,actor  tt0050986,tt0050976,tt0069467,tt0083922

# %%
dframe.size
# Out:
# 55593402

# %%
dframe.size(n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-29059cf6a192> in <module>()
# ----> 1 dframe.size(n)
#
# NameError: name 'n' is not defined

# %%
len(dframe)
# Out:
# 9265567

# %%
dframe=pd.read_csv("name.basics.tsv",sep='\t')

# %%
dframe
# Out:
#             nconst          primaryName birthYear deathYear  \
# 0        nm0000001         Fred Astaire      1899      1987
# 1        nm0000002        Lauren Bacall      1924      2014
# 2        nm0000003      Brigitte Bardot      1934        \N
# 3        nm0000004         John Belushi      1949      1982
# 4        nm0000005       Ingmar Bergman      1918      2007
# 5        nm0000006       Ingrid Bergman      1915      1982
# 6        nm0000007      Humphrey Bogart      1899      1957
# 7        nm0000008        Marlon Brando      1924      2004
# 8        nm0000009       Richard Burton      1925      1984
# 9        nm0000010         James Cagney      1899      1986
# 10       nm0000011          Gary Cooper      1901      1961
# 11       nm0000012          Bette Davis      1908      1989
# 12       nm0000013            Doris Day      1922        \N
# 13       nm0000014  Olivia de Havilland      1916        \N
# 14       nm0000015           James Dean      1931      1955
# ...

# %%
mask=dframe["deathYear"].isnull()

# %%
dframe[mask]
# Out:
# Empty DataFrame
# Columns: [nconst, primaryName, birthYear, deathYear, primaryProfession, knownForTitles]
# Index: []

# %%
mask=dframe['deathYear']=="\\N"

# %%
dframe[mask]
# Out:
#             nconst          primaryName birthYear deathYear  \
# 2        nm0000003      Brigitte Bardot      1934        \N
# 12       nm0000013            Doris Day      1922        \N
# 13       nm0000014  Olivia de Havilland      1916        \N
# 17       nm0000018         Kirk Douglas      1916        \N
# 46       nm0000047         Sophia Loren      1934        \N
# 78       nm0000079         Raquel Welch      1940        \N
# 82       nm0000083          Alan Miller        \N        \N
# 83       nm0000084              Li Gong      1965        \N
# 84       nm0000085       Henner Hofmann      1950        \N
# 86       nm0000087       Elena Koreneva      1953        \N
# 89       nm0000090  Armin Mueller-Stahl      1930        \N
# 90       nm0000091         Gérard Pirès      1942        \N
# 91       nm0000092          John Cleese      1939        \N
# 92       nm0000093            Brad Pitt      1963        \N
# 93       nm0000094            J. Reifel        \N        \N
# ...

# %%
len(dframe.isnull())
# Out:
# 9265567

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9265567 entries, 0 to 9265566
# Data columns (total 6 columns):
# nconst               object
# primaryName          object
# birthYear            object
# deathYear            object
# primaryProfession    object
# knownForTitles       object
# dtypes: object(6)
# memory usage: 424.1+ MB

# %%
dframe['nconst'].astype('str')
# Out:
# 0          nm0000001
# 1          nm0000002
# 2          nm0000003
# 3          nm0000004
# 4          nm0000005
# 5          nm0000006
# 6          nm0000007
# 7          nm0000008
# 8          nm0000009
# 9          nm0000010
# 10         nm0000011
# 11         nm0000012
# 12         nm0000013
# 13         nm0000014
# 14         nm0000015
# 15         nm0000016
# 16         nm0000017
# 17         nm0000018
# 18         nm0000019
# 19         nm0000020
# 20         nm0000021
# 21         nm0000022
# 22         nm0000023
# 23         nm0000024
# 24         nm0000025
# 25         nm0000026
# 26         nm0000027
# 27         nm0000028
# 28         nm0000029
# 29         nm0000030
#              ...
# 9265537    nm9993689
# 9265538    nm9993690
# 9265539    nm9993691
# 9265540    nm9993692
# 9265541    nm9993693
# 9265542    nm9993694
# 9265543    nm9993696
# 9265544    nm9993697
# 9265545    nm9993698
# 9265546    nm9993699
# 9265547    nm9993700
# 9265548    nm9993701
# ...

# %%
dframe['primaryName'].astype('str')
# Out:
# 0                 Fred Astaire
# 1                Lauren Bacall
# 2              Brigitte Bardot
# 3                 John Belushi
# 4               Ingmar Bergman
# 5               Ingrid Bergman
# 6              Humphrey Bogart
# 7                Marlon Brando
# 8               Richard Burton
# 9                 James Cagney
# 10                 Gary Cooper
# 11                 Bette Davis
# 12                   Doris Day
# 13         Olivia de Havilland
# 14                  James Dean
# 15             Georges Delerue
# 16            Marlene Dietrich
# 17                Kirk Douglas
# 18            Federico Fellini
# 19                 Henry Fonda
# 20               Joan Fontaine
# 21                 Clark Gable
# 22                Judy Garland
# 23                John Gielgud
# 24             Jerry Goldsmith
# 25                  Cary Grant
# 26               Alec Guinness
# 27               Rita Hayworth
# 28           Margaux Hemingway
# 29              Audrey Hepburn
# ...

# %%
mask=dframe['birthYear']=='\\N'

# %%
dframe[mask]
# Out:
#             nconst            primaryName birthYear deathYear  \
# 82       nm0000083            Alan Miller        \N        \N
# 93       nm0000094              J. Reifel        \N        \N
# 646      nm0000647           Alan Smithee        \N        \N
# 711      nm0000712            Steve Cohen        \N        \N
# 1267     nm0001269           Cynthia Gibb        \N        \N
# 1890     nm0001892             Steve Rice        \N        \N
# 1895     nm0001897          John M. Davis        \N        \N
# 2072     nm0002074           Sally Fields        \N        \N
# 2149     nm0002151          Frank DeMarco        \N        \N
# 2150     nm0002152            Jörg Widmer        \N        \N
# 2168     nm0002170         Ashok Amritraj        \N        \N
# 2197     nm0002200         Richard Walden        \N        \N
# 2200     nm0002203           Loren Miller        \N        \N
# 2201     nm0002204      Michael A. Dawson        \N        \N
# ...

# %%
dframe[['birthYear','deathYear']]=dframe[['birthYear','deathYear']].replace('\\N',np.nan)

# %%
mask=dframe['birthYear']==np.nan

# %%
dframe[mask]
# Out:
# Empty DataFrame
# Columns: [nconst, primaryName, birthYear, deathYear, primaryProfession, knownForTitles]
# Index: []

# %%
dframe[['knownForTitles']]=dframe[['knownForTitles']].replace('\\N',np.nan)

# %%
dframe
# Out:
#             nconst          primaryName birthYear deathYear  \
# 0        nm0000001         Fred Astaire      1899      1987
# 1        nm0000002        Lauren Bacall      1924      2014
# 2        nm0000003      Brigitte Bardot      1934       NaN
# 3        nm0000004         John Belushi      1949      1982
# 4        nm0000005       Ingmar Bergman      1918      2007
# 5        nm0000006       Ingrid Bergman      1915      1982
# 6        nm0000007      Humphrey Bogart      1899      1957
# 7        nm0000008        Marlon Brando      1924      2004
# 8        nm0000009       Richard Burton      1925      1984
# 9        nm0000010         James Cagney      1899      1986
# 10       nm0000011          Gary Cooper      1901      1961
# 11       nm0000012          Bette Davis      1908      1989
# 12       nm0000013            Doris Day      1922       NaN
# 13       nm0000014  Olivia de Havilland      1916       NaN
# 14       nm0000015           James Dean      1931      1955
# ...

# %%
dframe2=pd.read_csv("name.basics.tsv",sep='\t')

# %%
dframe2
# Out:
#             nconst          primaryName birthYear deathYear  \
# 0        nm0000001         Fred Astaire      1899      1987
# 1        nm0000002        Lauren Bacall      1924      2014
# 2        nm0000003      Brigitte Bardot      1934        \N
# 3        nm0000004         John Belushi      1949      1982
# 4        nm0000005       Ingmar Bergman      1918      2007
# 5        nm0000006       Ingrid Bergman      1915      1982
# 6        nm0000007      Humphrey Bogart      1899      1957
# 7        nm0000008        Marlon Brando      1924      2004
# 8        nm0000009       Richard Burton      1925      1984
# 9        nm0000010         James Cagney      1899      1986
# 10       nm0000011          Gary Cooper      1901      1961
# 11       nm0000012          Bette Davis      1908      1989
# 12       nm0000013            Doris Day      1922        \N
# 13       nm0000014  Olivia de Havilland      1916        \N
# 14       nm0000015           James Dean      1931      1955
# ...

# %%
dframe[['birthYear','deathYear']]=dframe[['birthYear','deathYear']].replace(np.nan,0)

# %%
dframe
# Out:
#             nconst          primaryName birthYear deathYear  \
# 0        nm0000001         Fred Astaire      1899      1987
# 1        nm0000002        Lauren Bacall      1924      2014
# 2        nm0000003      Brigitte Bardot      1934         0
# 3        nm0000004         John Belushi      1949      1982
# 4        nm0000005       Ingmar Bergman      1918      2007
# 5        nm0000006       Ingrid Bergman      1915      1982
# 6        nm0000007      Humphrey Bogart      1899      1957
# 7        nm0000008        Marlon Brando      1924      2004
# 8        nm0000009       Richard Burton      1925      1984
# 9        nm0000010         James Cagney      1899      1986
# 10       nm0000011          Gary Cooper      1901      1961
# 11       nm0000012          Bette Davis      1908      1989
# 12       nm0000013            Doris Day      1922         0
# 13       nm0000014  Olivia de Havilland      1916         0
# 14       nm0000015           James Dean      1931      1955
# ...

# %%
dframe
# Out:
#             nconst          primaryName birthYear deathYear  \
# 0        nm0000001         Fred Astaire      1899      1987
# 1        nm0000002        Lauren Bacall      1924      2014
# 2        nm0000003      Brigitte Bardot      1934         0
# 3        nm0000004         John Belushi      1949      1982
# 4        nm0000005       Ingmar Bergman      1918      2007
# 5        nm0000006       Ingrid Bergman      1915      1982
# 6        nm0000007      Humphrey Bogart      1899      1957
# 7        nm0000008        Marlon Brando      1924      2004
# 8        nm0000009       Richard Burton      1925      1984
# 9        nm0000010         James Cagney      1899      1986
# 10       nm0000011          Gary Cooper      1901      1961
# 11       nm0000012          Bette Davis      1908      1989
# 12       nm0000013            Doris Day      1922         0
# 13       nm0000014  Olivia de Havilland      1916         0
# 14       nm0000015           James Dean      1931      1955
# ...

# %%
dframe2 = dframe[dframe[['primaryProfession','knownForTitles']].notnull()]

# %%
dframe.isnull().sum()
# Out:
# nconst                     0
# primaryName                0
# birthYear                  0
# deathYear                  0
# primaryProfession    1696793
# knownForTitles       1328672
# dtype: int64

# %%
dframe2=dframe.dropna(subset=['primaryProfession', 'knownForTitles'], how='all')

# %%
dframe2['knownForTitles'].astype('str')
# Out:
# 0          tt0043044,tt0050419,tt0053137,tt0072308
# 1          tt0071877,tt0037382,tt0117057,tt0038355
# 2          tt0049189,tt0054452,tt0059956,tt0057345
# 3          tt0080455,tt0072562,tt0077975,tt0078723
# 4          tt0050986,tt0050976,tt0069467,tt0083922
# 5          tt0038787,tt0038109,tt0071877,tt0036855
# 6          tt0043265,tt0034583,tt0033870,tt0037382
# 7          tt0070849,tt0068646,tt0078788,tt0047296
# 8          tt0057877,tt0059749,tt0061184,tt0087803
# 9          tt0031867,tt0029870,tt0055256,tt0035575
# 10         tt0027996,tt0035211,tt0034167,tt0044706
# 11         tt0042192,tt0056687,tt0035140,tt0031210
# 12         tt0048317,tt0053172,tt0055100,tt0060463
# 13         tt0029843,tt0041452,tt0040806,tt0031381
# 14         tt0049261,tt0048545,tt0048028,tt0045458
# 15         tt0080610,tt0096320,tt0091763,tt0069946
# 16         tt0051201,tt0021156,tt0055031,tt0052311
# 17         tt0054331,tt0049456,tt0052365,tt0080736
# ...

# %%
dframe=dframe2

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8364043 entries, 0 to 9265565
# Data columns (total 6 columns):
# nconst               object
# primaryName          object
# birthYear            object
# deathYear            object
# primaryProfession    object
# knownForTitles       object
# dtypes: object(6)
# memory usage: 446.7+ MB

# %%
dframe["deathYear"]=dframe["deathYear"].astype("int")
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8364043 entries, 0 to 9265565
# Data columns (total 6 columns):
# nconst               object
# primaryName          object
# birthYear            int32
# deathYear            int32
# primaryProfession    object
# knownForTitles       object
# dtypes: int32(2), object(4)
# memory usage: 382.9+ MB

# %%
dframe.isnull().sum()
# Out:
# nconst                    0
# primaryName               0
# birthYear                 0
# deathYear                 0
# primaryProfession    795269
# knownForTitles       427148
# dtype: int64

# %%
dframe2=dframe.dropna(subset=['primaryProfession','knownForTitles'], how='any')

# %%
dframe2
# Out:
#             nconst                primaryName  birthYear  deathYear  \
# 0        nm0000001               Fred Astaire       1899       1987
# 1        nm0000002              Lauren Bacall       1924       2014
# 2        nm0000003            Brigitte Bardot       1934          0
# 3        nm0000004               John Belushi       1949       1982
# 4        nm0000005             Ingmar Bergman       1918       2007
# 5        nm0000006             Ingrid Bergman       1915       1982
# 6        nm0000007            Humphrey Bogart       1899       1957
# 7        nm0000008              Marlon Brando       1924       2004
# 8        nm0000009             Richard Burton       1925       1984
# 9        nm0000010               James Cagney       1899       1986
# 10       nm0000011                Gary Cooper       1901       1961
# 11       nm0000012                Bette Davis       1908       1989
# 12       nm0000013                  Doris Day       1922          0
# ...

# %%
dframe2.isnull().sum()
# Out:
# nconst               0
# primaryName          0
# birthYear            0
# deathYear            0
# primaryProfession    0
# knownForTitles       0
# dtype: int64

# %%
result = dframe2.reset_index(drop = True)

# %%
result
# Out:
#             nconst                primaryName  birthYear  deathYear  \
# 0        nm0000001               Fred Astaire       1899       1987
# 1        nm0000002              Lauren Bacall       1924       2014
# 2        nm0000003            Brigitte Bardot       1934          0
# 3        nm0000004               John Belushi       1949       1982
# 4        nm0000005             Ingmar Bergman       1918       2007
# 5        nm0000006             Ingrid Bergman       1915       1982
# 6        nm0000007            Humphrey Bogart       1899       1957
# 7        nm0000008              Marlon Brando       1924       2004
# 8        nm0000009             Richard Burton       1925       1984
# 9        nm0000010               James Cagney       1899       1986
# 10       nm0000011                Gary Cooper       1901       1961
# 11       nm0000012                Bette Davis       1908       1989
# 12       nm0000013                  Doris Day       1922          0
# ...

# %%
result.to_csv('Desktop/person_information_2.csv',index=False)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7141626 entries, 0 to 7141625
# Data columns (total 6 columns):
# nconst               object
# primaryName          object
# birthYear            int32
# deathYear            int32
# primaryProfession    object
# knownForTitles       object
# dtypes: int32(2), object(4)
# memory usage: 272.4+ MB
